# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
# !pip install numpy==1.17.4

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %% [markdown]
# **Go to your google drive and make a folder named 'Desktop' without the quotes**

# %%
# %cd '/content/gdrive/My Drive/Desktop/'
# Out:
# /content/gdrive/My Drive/Desktop

# %%
# !git clone https://github.com/tensorflow/models.git
# Out:
# Cloning into 'models'...
# remote: Enumerating objects: 35, done.
# remote: Counting objects: 100% (35/35), done.
# remote: Compressing objects: 100% (30/30), done.
# remote: Total 35468 (delta 13), reused 21 (delta 5), pack-reused 35433
# Receiving objects: 100% (35468/35468), 512.91 MiB | 13.34 MiB/s, done.
# Resolving deltas: 100% (23033/23033), done.
# Checking out files: 100% (2517/2517), done.

# %%
# !apt-get install protobuf-compiler python-pil python-lxml python-tk
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# protobuf-compiler is already the newest version (3.0.0-9.1ubuntu1).
# python-tk is already the newest version (2.7.17-1~18.04).
# The following additional packages will be installed:
#   python-bs4 python-chardet python-html5lib python-olefile
#   python-pkg-resources python-six python-webencodings
# Suggested packages:
#   python-genshi python-lxml-dbg python-lxml-doc python-pil-doc python-pil-dbg
#   python-setuptools
# The following NEW packages will be installed:
#   python-bs4 python-chardet python-html5lib python-lxml python-olefile
#   python-pil python-pkg-resources python-six python-webencodings
# 0 upgraded, 9 newly installed, 0 to remove and 31 not upgraded.
# Need to get 1,818 kB of archives.
# After this operation, 7,685 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/main amd64 python-bs4 all 4.6.0-1 [67.9 kB]
# ...

# %%
# %cd /content/gdrive/My Drive/Desktop/models/research/
# Out:
# /content/gdrive/My Drive/Desktop/models/research

# %%
# !protoc object_detection/protos/*.proto --python_out=.
# Out:
# object_detection/protos/input_reader.proto: warning: Import object_detection/protos/image_resizer.proto but not used.

# %%
import os
os.environ['PYTHONPATH'] += ':/content/gdrive/My Drive/Desktop/models/research/:/content/gdrive/My Drive/Desktop/models/research/slim'

# %%
# !python setup.py build
# !python setup.py install
# Out:
# running build
# running build_py
# creating build
# creating build/lib
# creating build/lib/object_detection
# copying object_detection/__init__.py -> build/lib/object_detection
# copying object_detection/eval_util.py -> build/lib/object_detection
# copying object_detection/eval_util_test.py -> build/lib/object_detection
# copying object_detection/export_inference_graph.py -> build/lib/object_detection
# copying object_detection/export_tflite_ssd_graph.py -> build/lib/object_detection
# copying object_detection/export_tflite_ssd_graph_lib.py -> build/lib/object_detection
# copying object_detection/export_tflite_ssd_graph_lib_test.py -> build/lib/object_detection
# copying object_detection/exporter.py -> build/lib/object_detection
# copying object_detection/exporter_test.py -> build/lib/object_detection
# copying object_detection/inputs.py -> build/lib/object_detection
# copying object_detection/inputs_test.py -> build/lib/object_detection
# ...

# %%
import time, psutil
Start = time.time()- psutil.boot_time()
Left= 12*3600 - Start
print('Time remaining for this session is: ', Left/3600, " hours")
# Out:
# Time remaining for this session is:  11.83796321067545  hours

# %%
# %cd /content/gdrive/My Drive/Desktop/models/research/object_detection/builders/
# !python model_builder_test.py
# Out:
# /content/gdrive/My Drive/Desktop/models/research/object_detection/builders

# %%
# %cd /content/gdrive/My Drive/Desktop/models/research/object_detection/
# Out:
# /content/gdrive/My Drive/Desktop/models/research/object_detection

# %%
# !git clone https://github.com/NilsCode/FRCNN-ocr.git
# Out:
# Cloning into 'FRCNN-ocr'...
# remote: Enumerating objects: 80, done.
# remote: Counting objects: 100% (80/80), done.
# remote: Compressing objects: 100% (75/75), done.
# remote: Total 80 (delta 32), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (80/80), done.

# %%
# !mkdir -p images/train/ images/test/ training/
# !mkdir -p letterimages/train letterimages/test/

# %%
# !mv FRCNN-ocr/Completedataset.py Completedataset.py
# !mv FRCNN-ocr/example.py example.py
# !mv FRCNN-ocr/labelmap.pbtxt training/

# %%
# !python example.py
# Out:
# Done Generating  0  images..
# Done Generating  10  images..
# Done Generating  20  images..
# Done Generating  30  images..
# Done Generating  40  images..
# Done Generating  50  images..
# Done Generating  60  images..
# Done Generating  70  images..
# Done Generating  80  images..
# Done Generating  90  images..
# Done Generating  100  images..
# Done Generating  110  images..
# Done Generating  120  images..
# Done Generating  130  images..
# Done Generating  140  images..
# Done Generating  150  images..
# Done Generating  160  images..
# Done Generating  170  images..
# Done Generating  180  images..
# Done Generating  190  images..
# Done Generating  0  images..
# Done Generating  10  images..
# Done Generating  20  images..
# Done Generating  30  images..
# Done Generating  40  images..
# Done Writing Train Lables to file..
# Done Writing Train Lables to file..
# Done writing  0  images to folder..
# Done writing  10  images to folder..
# Done writing  20  images to folder..
# ...

# %%
# %ls
# Out:
# anchor_generators/                   inputs.py
# box_coders/                          inputs_test.py
# builders/                            legacy/
# Completedataset.py                   letterimages/
# CONTRIBUTING.md                      matchers/
# core/                                meta_architectures/
# data/                                metrics/
# data_decoders/                       model_hparams.py
# dataset_tools/                       model_lib.py
# dockerfiles/                         model_lib_test.py
# eval_util.py                         model_lib_v2.py
# eval_util_test.py                    model_lib_v2_test.py
# example.py                           model_main.py
# exporter.py                          models/
# exporter_test.py                     model_tpu_main.py
# export_inference_graph.py            object_detection_tutorial.ipynb
# export_tflite_ssd_graph_lib.py       predictors/
# export_tflite_ssd_graph_lib_test.py  protos/
# ...

# %%
# !python generate_tfrecord.py --csv_input=images/traindata.csv --output_path=train.record --img_path=images/train
# Out:
# Successfully created the TFRecords: /content/gdrive/My Drive/Desktop/models/research/object_detection/train.record

# %%
# !python generate_tfrecord.py --csv_input=images/testdata.csv --output_path=test.record --img_path=images/test
# Out:
# Successfully created the TFRecords: /content/gdrive/My Drive/Desktop/models/research/object_detection/test.record

# %%
# !wget http://download.tensorflow.org/models/object_detection/faster_rcnn_inception_v2_coco_2018_01_28.tar.gz
# !tar -xvf faster_rcnn_inception_v2_coco_2018_01_28.tar.gz
# Out:
# --2020-05-22 10:22:20--  http://download.tensorflow.org/models/object_detection/faster_rcnn_inception_v2_coco_2018_01_28.tar.gz
# Resolving download.tensorflow.org (download.tensorflow.org)... 172.217.214.128, 2607:f8b0:4001:c05::80
# Connecting to download.tensorflow.org (download.tensorflow.org)|172.217.214.128|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 149119618 (142M) [application/x-tar]
# Saving to: ‘faster_rcnn_inception_v2_coco_2018_01_28.tar.gz’
#
# faster_rcnn_incepti 100%[===================>] 142.21M  52.6MB/s    in 2.7s
#
# 2020-05-22 10:22:23 (52.6 MB/s) - ‘faster_rcnn_inception_v2_coco_2018_01_28.tar.gz’ saved [149119618/149119618]
#
# faster_rcnn_inception_v2_coco_2018_01_28/
# faster_rcnn_inception_v2_coco_2018_01_28/model.ckpt.index
# faster_rcnn_inception_v2_coco_2018_01_28/checkpoint
# faster_rcnn_inception_v2_coco_2018_01_28/pipeline.config
# faster_rcnn_inception_v2_coco_2018_01_28/model.ckpt.data-00000-of-00001
# ...

# %%
cd training/
# Out:
# /content/gdrive/My Drive/Desktop/models/research/object_detection/training

# %%
# !wget https://raw.githubusercontent.com/tensorflow/models/master/research/object_detection/samples/configs/faster_rcnn_inception_v2_coco.config
# Out:
# --2020-05-22 10:31:18--  https://raw.githubusercontent.com/tensorflow/models/master/research/object_detection/samples/configs/faster_rcnn_inception_v2_coco.config
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3738 (3.7K) [text/plain]
# Saving to: ‘faster_rcnn_inception_v2_coco.config’
#
# faster_rcnn_incepti 100%[===================>]   3.65K  --.-KB/s    in 0.001s
#
# 2020-05-22 10:31:18 (3.33 MB/s) - ‘faster_rcnn_inception_v2_coco.config’ saved [3738/3738]

# %%
# !python model_main.py --logtostderr --model_dir=training/ --pipeline_config_path=training/faster_rcnn_inception_v2_coco.config
# Out:
# WARNING:tensorflow:From model_main.py:109: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# WARNING:tensorflow:From /content/gdrive/My Drive/Desktop/models/research/object_detection/utils/config_util.py:137: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.
#
# W0522 10:41:56.592571 139862188758912 module_wrapper.py:139] From /content/gdrive/My Drive/Desktop/models/research/object_detection/utils/config_util.py:137: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.
#
# WARNING:tensorflow:From /content/gdrive/My Drive/Desktop/models/research/object_detection/model_lib.py:685: The name tf.logging.warning is deprecated. Please use tf.compat.v1.logging.warning instead.
#
# ...

# %%
# !python export_inference_graph.py --input_type image_tensor --pipeline_config_path training/faster_rcnn_inception_v2_coco.config --trained_checkpoint_prefix training/model.ckpt-28313 --output_directory inference_graph
# Out:
# WARNING:tensorflow:From export_inference_graph.py:162: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# WARNING:tensorflow:From export_inference_graph.py:145: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.
#
# W0522 13:06:28.290032 139786145515392 module_wrapper.py:139] From export_inference_graph.py:145: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.
#
# WARNING:tensorflow:From /content/gdrive/My Drive/Desktop/models/research/object_detection/meta_architectures/faster_rcnn_meta_arch.py:151: The name tf.AUTO_REUSE is deprecated. Please use tf.compat.v1.AUTO_REUSE instead.
#
# W0522 13:06:28.297684 139786145515392 module_wrapper.py:139] From /content/gdrive/My Drive/Desktop/models/research/object_detection/meta_architectures/faster_rcnn_meta_arch.py:151: The name tf.AUTO_REUSE is deprecated. Please use tf.compat.v1.AUTO_REUSE instead.
#
# ...

# %%
# !wget https://github.com/NilsCode/object_detection/blob/master/object_detection_image.py
# Out:
# --2020-05-22 13:25:58--  https://github.com/NilsCode/object_detection/blob/master/object_detection_image.py
# Resolving github.com (github.com)... 140.82.113.4
# Connecting to github.com (github.com)|140.82.113.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘object_detection_image.py’
#
# object_detection_im     [ <=>                ] 123.79K  --.-KB/s    in 0.08s
#
# 2020-05-22 13:25:59 (1.59 MB/s) - ‘object_detection_image.py’ saved [126759]

# %%
# !python object_detection_image.py
# Out:
# Load graph
# WARNING:tensorflow:From object_detection_image.py:66: The name tf.GraphDef is deprecated. Please use tf.compat.v1.GraphDef instead.
#
# WARNING:tensorflow:From object_detection_image.py:67: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.
#
# WARNING:tensorflow:From object_detection_image.py:72: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2020-05-22 13:38:46.467990: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-05-22 13:38:46.498144: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-05-22 13:38:46.499999: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:00:04.0
# ...
